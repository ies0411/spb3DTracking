# %%
# 0 1 Cyclist 0 0 -1.936993 737.619499 161.531951 931.112229 374.000000 1.739063 0.824591 1.785241 1.640400 1.675660 5.776261 -1.675458
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_path ='../sample/image/0000/000001.png'
image = cv2.imread(img_path)

# %%
plt.subplots(1, 1, figsize=(15, 7))
plt.imshow(image)

# %%
# 바운딩 박스를 그릴 좌표 (x1, y1), (x2, y2)

# 0 1 Cyclist 0 0 -1.936993 737.619499 161.531951 931.112229 374.000000                1.739063           0.824591           1.785241           1.640400  1.675660  5.776261 -1.675458
# 0 1 Cyclist -1 -1 -10 780.4826717210284 159.8778635586062 877.2140909981784 374.0  1.558581829071045  0.5644908547401428 1.7703676223754883 1.6415303 1.6815022 5.775603 6.4621663093566895 
# 0 1 Cyclist -1 -1 -10 780.4816742262454 159.87844870575617 877.2146301301946 374.0 1.5585695505142212 0.5645090341567993 1.770362138748169 1.6415281 1.6815007 5.775604 6.462169170379639 

# 0 1 Cyclist -1 -1 -10 781.2536101358929 165.03948357995725 879.5344455631133 374.0 1.5672513246536255 0.5660192966461182 1.7846254110336304 1.6501776 1.7313852 5.7671566 6.458888530731201 
# 0 1 Cyclist -1 -1 -10 781.2536101358929 165.03948357995725 879.5344455631133 374.0 1.5672513246536255 0.5660192966461182 1.7846254110336304 1.6501776 1.7313852 5.7671566 6.458888530731201 
# 0 1 Cyclist -1 -1 -10 781.2536101358929 165.03948357995725 879.5344455631133 374.0 1.5672513246536255 0.5660192966461182 1.7846254110336304 1.6501776 1.7313852 5.7671566 6.458888530731201 

# 1 1 Pedestrian -1 -1 -10 1144.0606647918817 170.81826800853932 1236.2822524946039 328.03369032905584 0.670465321637768 0.6233065619930802 1.673996165800626 6.434494 1.652678 8.101358 0.3474848825922825 


x1, y1, x2, y2 = 1144 , 170, 1236,328

# 바운딩 박스 색상 및 두께 설정
color = (0, 255, 0)  # 초록색 (BGR 형식)
thickness = 2  # 선 두께

# 이미지에 바운딩 박스 그리기
image_with_bbox = cv2.rectangle(image, (x1, y1), (x2, y2), color, thickness)

# %%
plt.subplots(1, 1, figsize=(15, 7))
plt.imshow(image_with_bbox)
